# %%
import pandas as pd

# %%
df = pd.read_csv("population.csv")

# %%
df
# Out:
#                     Country Name Country Code   Population   Lifespan  \
# 0                          Aruba          ABW     107195.0  76.434000
# 1    Africa Eastern and Southern          AFE  694665117.0  64.325702
# 2                    Afghanistan          AFG   39835428.0  65.173000
# 3     Africa Western and Central          AFW  470898870.0  58.445953
# 4                         Angola          AGO   33933611.0  61.487000
# ..                           ...          ...          ...        ...
# 261                       Kosovo          XKX    1806279.0  71.087805
# 262                  Yemen, Rep.          YEM   30490639.0  66.181000
# 263                 South Africa          ZAF   60041996.0  64.379000
# 264                       Zambia          ZMB   18920657.0  64.194000
# 265                     Zimbabwe          ZWE   15092171.0  61.738000
#
#                          Region          IncomeGroup  Fertility  \
# ...

# %%
for i in (range(len(df))):
    dfc = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_frate\\'+str(df['Country Code'][i])+'.csv')
    dfc['inc']=0
    dfc['per']=0
    for x in range(1,len(dfc)):
        dfc['inc'][x]=dfc['fertility'][x]-dfc['fertility'][x-1]
        dfc['per'][x]=(dfc['inc'][x]/dfc['fertility'][x-1])*100
    sum_per=dfc['per'].sum()
    avg_per=sum_per/59
    df['mean_yearly_fertility_change_percentage'][i]=avg_per
    dfc_10=dfc.iloc[49:60]
    dfc_20=dfc.iloc[39:60]
    avg_per_10=dfc_10['per'].sum()/10
    avg_per_20=dfc_20['per'].sum()/20
    df['mean_fertility_10years'][i]=avg_per_10
    df['mean_fertility_20years'][i]=avg_per_20
# Out:
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_13596\4263160217.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['inc'][x]=dfc['fertility'][x]-dfc['fertility'][x-1]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_13596\4263160217.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['per'][x]=(dfc['inc'][x]/dfc['fertility'][x-1])*100
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_13596\4263160217.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['yearly_decrease_to_zero_per']=0

# %%
import numpy
import math

# %%
for i in range(len(df)):
    df['yearly_decrease_to_zero_per'][i]=df['Population'][i]/df['Lifespan'][i]
    df['yearly_decrease_to_zero_per'][i]=math.trunc(numpy.nan_to_num(df['yearly_decrease_to_zero_per'][i]))

# %%
df['yearly_decrease_to_zero_per'][0]
# Out:
# 1402.0

# %%
for i in range(len(df)):
    df['mean_yearly_fertility_change_percentage']=round(df['mean_yearly_fertility_change_percentage'],3)
    df['mean_fertility_10years']=round(df['mean_fertility_10years'],3)
    df['mean_fertility_20years']=round(df['mean_fertility_20years'],3)

# %%
df
# Out:
#                     Country Name Country Code   Population   Lifespan  \
# 0                          Aruba          ABW     107195.0  76.434000
# 1    Africa Eastern and Southern          AFE  694665117.0  64.325702
# 2                    Afghanistan          AFG   39835428.0  65.173000
# 3     Africa Western and Central          AFW  470898870.0  58.445953
# 4                         Angola          AGO   33933611.0  61.487000
# ..                           ...          ...          ...        ...
# 261                       Kosovo          XKX    1806279.0  71.087805
# 262                  Yemen, Rep.          YEM   30490639.0  66.181000
# 263                 South Africa          ZAF   60041996.0  64.379000
# 264                       Zambia          ZMB   18920657.0  64.194000
# 265                     Zimbabwe          ZWE   15092171.0  61.738000
#
#                          Region          IncomeGroup  Fertility  \
# ...

# %%
df.to_csv('countries.csv', index=False)

# %%
df
# Out:
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_13596\2981914928.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_yearly_fertility_change_percentage'][0]=avg_per

# %%
dfc = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_frate\\'+str(df['Country Code'][0])+'.csv')

# %%
dfc['inc']=0
dfc['per']=0

# %%
dfc
# Out:
#     year  fertility  inc  per
# 0   1960      4.820    0    0
# 1   1961      4.655    0    0
# 2   1962      4.471    0    0
# 3   1963      4.271    0    0
# 4   1964      4.059    0    0
# ..   ...        ...  ...  ...
# 56  2016      1.872    0    0
# 57  2017      1.886    0    0
# 58  2018      1.896    0    0
# 59  2019      1.901    0    0
# 60  2020      1.901    0    0
#
# [61 rows x 4 columns]

# %%
for i in range(1,len(dfc)):
    dfc['inc'][i]=dfc['fertility'][i]-dfc['fertility'][i-1]
    dfc['per'][i]=(dfc['inc'][i]/dfc['fertility'][i-1])*100
# Out:
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_13596\654791706.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['inc'][i]=dfc['fertility'][i]-dfc['fertility'][i-1]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_13596\654791706.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['per'][i]=(dfc['inc'][i]/dfc['fertility'][i-1])*100

# %%
dfc
# Out:
#     year  fertility    inc       per
# 0   1960      4.820  0.000  0.000000
# 1   1961      4.655 -0.165 -3.423237
# 2   1962      4.471 -0.184 -3.952739
# 3   1963      4.271 -0.200 -4.473272
# 4   1964      4.059 -0.212 -4.963709
# ..   ...        ...    ...       ...
# 56  2016      1.872  0.018  0.970874
# 57  2017      1.886  0.014  0.747863
# 58  2018      1.896  0.010  0.530223
# 59  2019      1.901  0.005  0.263713
# 60  2020      1.901  0.000  0.000000
#
# [61 rows x 4 columns]

# %%
sum_per=dfc['per'].sum()

# %%
sum_per
# Out:
# -91.23892323765898

# %%
avg_per=sum_per/59

# %%
avg_per
# Out:
# -1.5464224277569318

# %%
dfc_10=dfc.iloc[39:60]

# %%
dfc_10
# Out:
#     year  fertility    inc       per
# 39  1999      3.786 -0.053 -1.380568
# 40  2000      3.748 -0.038 -1.003698
# 41  2001      3.725 -0.023 -0.613661
# 42  2002      3.718 -0.007 -0.187919
# 43  2003      3.725  0.007  0.188273
# 44  2004      3.744  0.019  0.510067
# 45  2005      3.775  0.031  0.827991
# 46  2006      3.819  0.044  1.165563
# 47  2007      3.873  0.054  1.413983
# 48  2008      3.931  0.058  1.497547
# 49  2009      3.988  0.057  1.450013
# 50  2010      4.034  0.046  1.153460
# 51  2011      4.059  0.025  0.619732
# 52  2012      4.058 -0.001 -0.024637
# 53  2013      4.030 -0.028 -0.689995
# 54  2014      3.974 -0.056 -1.389578
# 55  2015      3.896 -0.078 -1.962758
# 56  2016      3.804 -0.092 -2.361396
# 57  2017      3.707 -0.097 -2.549947
# 58  2018      3.615 -0.092 -2.481791
# 59  2019      3.531 -0.084 -2.323651
