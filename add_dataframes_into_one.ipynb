# %%
import pandas as pd

# %%
df = pd.read_csv("countries.csv")

# %%
dfr = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_real\\'+str(df['Country Code'][0])+'.csv')

# %%
df10 = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_10\\'+str(df['Country Code'][0])+'.csv')

# %%
df20 = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_20\\'+str(df['Country Code'][0])+'.csv')

# %%
dfl = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_last\\'+str(df['Country Code'][0])+'.csv')

# %%
dfr
# Out:
#      year  population  fertility
# 0    1960   54208.000      4.820
# 1    1961   55434.000      4.655
# 2    1962   56234.000      4.471
# 3    1963   56699.000      4.271
# 4    1964   57029.000      4.059
# ..    ...         ...        ...
# 157  2117   35315.146      0.426
# 158  2118   34193.139      0.419
# 159  2119   33066.804      0.413
# 160  2120   31936.206      0.407
# 161  2121   30801.413      0.400
#
# [162 rows x 3 columns]

# %%
dfr.rename(columns = {'population':'60_years_popu'}, inplace = True)

# %%
dfr.rename(columns = {'fertility':'60_years_fert'}, inplace = True)

# %%
dfr['10_years_popu']=0
dfr['10_years_fert']=0
dfr['20_years_popu']=0
dfr['20_years_fert']=0
dfr['1_years_popu']=0
dfr['1_years_fert']=0

# %%
df10
# Out:
#      year  population  fertility
# 0    1960   54208.000      4.820
# 1    1961   55434.000      4.655
# 2    1962   56234.000      4.471
# 3    1963   56699.000      4.271
# 4    1964   57029.000      4.059
# ..    ...         ...        ...
# 157  2117  154346.350      4.008
# 158  2118  155640.992      4.039
# 159  2119  156956.667      4.071
# 160  2120  158293.540      4.102
# 161  2121  159651.776      4.134
#
# [162 rows x 3 columns]

# %%
for i in range(0,162):
    dfr['10_years_popu'][i]=df10['population'][i]
    dfr['10_years_fert'][i]=df10['fertility'][i]
    dfr['20_years_popu'][i]=df20['population'][i]
    dfr['20_years_fert'][i]=df20['fertility'][i]
    dfr['1_years_popu'][i]=dfl['population'][i]
    dfr['1_years_fert'][i]=dfl['fertility'][i]
# Out:
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\3464267627.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfr['10_years_popu'][i]=df10['population'][i]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\3464267627.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfr['10_years_fert'][i]=df10['fertility'][i]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\3464267627.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dfr
# Out:
#      year  60_years_popu  60_years_fert  10_years_fert  10_years_popu  \
# 0    1960      54208.000          4.820          4.820      54208.000
# 1    1961      55434.000          4.655          4.655      55434.000
# 2    1962      56234.000          4.471          4.471      56234.000
# 3    1963      56699.000          4.271          4.271      56699.000
# 4    1964      57029.000          4.059          4.059      57029.000
# ..    ...            ...            ...            ...            ...
# 157  2117      35315.146          0.426          4.008     154346.350
# 158  2118      34193.139          0.419          4.039     155640.992
# 159  2119      33066.804          0.413          4.071     156956.667
# 160  2120      31936.206          0.407          4.102     158293.540
# 161  2121      30801.413          0.400          4.134     159651.776
#
#      20_years_popu  20_years_fert  1_years_popu  1_years_fert
# 0        54208.000          4.820     54208.000         4.820
# ...

# %%
import math

# %%
dfx = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_real\\'+str(df['Country Code'][0])+'.csv')
dfx.rename(columns = {'population':'60_years_popu'}, inplace = True)
dfx.rename(columns = {'fertility':'60_years_fert'}, inplace = True)
dfx['60_years_popu']=0
dfx['60_years_fert']=0
dfx['10_years_popu']=0
dfx['10_years_fert']=0
dfx['20_years_popu']=0
dfx['20_years_fert']=0
dfx['1_years_popu']=0
dfx['1_years_fert']=0
dfx['no_growth_fert']=2.1
dfx['current_popu']=0
for x in range(len(df)):
    dfr = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_real\\'+str(df['Country Code'][x])+'.csv')
    df10 = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_10\\'+str(df['Country Code'][x])+'.csv')
    df20 = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_20\\'+str(df['Country Code'][x])+'.csv')
    dfl = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_last\\'+str(df['Country Code'][x])+'.csv')
    
    
    dfx['current_popu']+=df['Population'][x]
    for i in range(0,162):
        dfx['10_years_popu'][i]+=df10['population'][i]
        dfx['10_years_fert'][i]+=df10['fertility'][i]
        dfx['20_years_popu'][i]+=df20['population'][i]
        dfx['20_years_fert'][i]+=df20['fertility'][i]
        dfx['1_years_popu'][i]+=dfl['population'][i]
        dfx['1_years_fert'][i]+=dfl['fertility'][i]
        
        dfx['60_years_popu'][i]+=dfr['population'][i]
        dfx['60_years_fert'][i]+=dfr['fertility'][i]

for i in range(0,162):
dfx['10_years_fert'][i]= round(dfx['10_years_fert'][i]/266,2)
dfx['20_years_fert'][i]= round(dfx['20_years_fert'][i]/266,2)
dfx['60_years_fert'][i]= round(dfx['60_years_fert'][i]/266,2)
dfx['1_years_fert'][i]= round(dfx['1_years_fert'][i]/266,2)

dfx.to_csv('world.csv', index=False)
# Out:
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\1500719406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfx['10_years_popu'][i]+=df10['population'][i]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\1500719406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfx['10_years_fert'][i]+=df10['fertility'][i]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\1500719406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for x in range(len(df)):
    dfr = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_real\\'+str(df['Country Code'][x])+'.csv')
    df10 = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_10\\'+str(df['Country Code'][x])+'.csv')
    df20 = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_20\\'+str(df['Country Code'][x])+'.csv')
    dfl = pd.read_csv(r'C:\Users\Galbadral\Downloads\Intermediate python proejct 2\countries_population_last\\'+str(df['Country Code'][x])+'.csv')
    dfr.rename(columns = {'population':'60_years_popu'}, inplace = True)
    dfr.rename(columns = {'fertility':'60_years_fert'}, inplace = True)
    dfr['10_years_popu']=0
    dfr['10_years_fert']=0
    dfr['20_years_popu']=0
    dfr['20_years_fert']=0
    dfr['1_years_popu']=0
    dfr['1_years_fert']=0
    dfr['no_growth_fert']=2.1
    
    dfr['current_popu']=df['Population'][x]
    for i in range(0,162):
        dfr['10_years_popu'][i]=df10['population'][i]
        dfr['10_years_fert'][i]=df10['fertility'][i]
        dfr['20_years_popu'][i]=df20['population'][i]
        dfr['20_years_fert'][i]=df20['fertility'][i]
        dfr['1_years_popu'][i]=dfl['population'][i]
        dfr['1_years_fert'][i]=dfl['fertility'][i]
        
        dfr['60_years_popu'][i]=dfr['60_years_popu'][i]

    dfr.to_csv(str(df['Country Code'][x])+'.csv', index=False)
# Out:
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\1556470836.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfr['10_years_popu'][i]=df10['population'][i]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\1556470836.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfr['10_years_fert'][i]=df10['fertility'][i]
# C:\Users\Galbadral\AppData\Local\Temp\ipykernel_23944\1556470836.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
